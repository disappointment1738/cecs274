# %% [markdown]
# # MODULE 1 LAB ACTIVITIES
#
# Lab for week 1, spring 2023
#
# #### Date:
# 20 Jan 2023
#
# #### Due:
# 29 jan 2023

# %% [markdown]
# ## INTERFACES
#
# 1. (1 pt) Explain the difference between a data structure’s interface and its implementation.
#
# Answer: The difference between an interface and its implementation is that the interface describes what the data structure does compared to the implementation, which describes how the data structures does it.
#
# 2. (1 pt) True or False: An interface is also referred to as an abstract data type.
#
# Answer: True.
#
# 3. (1 pt) True or False: If two or more data structures implement a same interface, then they
# will have the same functionalities and same run-time efficiencies.
#
# Answer: False.
#
# 4. (a) (2 pts) Complete the sample project and submit it to the appropriate CodePost folder.
# The score you receive on CodePost will be the number of points you receive for this part
# of the lab activities. You can find directions for the sample project under Beachboard »
# Content » Module 1.
#
# Score: 10/10
#
# (b) (1 pt) Research: What is the purpose of `from ...` in each import statement of the
# header to the `main.py` file?
# `from Spider import Spider`
# `from Ant import Ant`
# `from Board import Board`
#
# Answer: `from` and `import` allows access to classes `Ant`, `Spider`, and `Board` from their respective ".py" files in main.py`
#
# (c) (1 pt) Research: Notice that both the `Ant` and `Spider` classes seem to take arguments
# `Insect` and `MobileCritter` in the declaration of the class:
# `class Ant(Insect, MobileCritter):
#     ...
#
# class Spider(Insect, MobileCritter):
#     ...`
#
# What is this syntax actually indicating?
#
# Answer: This syntax is actually indicating that the classes `Ant` and `Spider` inherit and implement from `Insect` and `MobileCritter`.
#
# 5. (1 pt) A UML (Unified Modeling Language) diagram depicts the relationships between two
# or more classes, data structures, interfaces, etc. in a program design. The symbol used to
# denote interface implementation is a dashed arrow with open tip from the data structure
# or class to the interface. For example, the UML diagram for the sample project would look
# like the following:
#     ***See sheet in BB***
# This diagram says that the `Ant` and `Spider` classes implement the methods of the MobileCritter
# interface. Hence, if we instantiate an `Ant` or `Spider` object, we are expecting to be able to
# call any of the methods listed in the `MobileCritter` interface on the object. Moreover, `Ant`
# and `Spider` override the `__str__` method, i.e., they define the string that should be returned
# when the function `str()` is called on an object of the class.
# Now, consider the UML diagram below:
#     ***See sheet in BB***
#
# Further reading: https://www.visual-paradigm.com/guide/uml-unified-modeling-language/what-is-uml/
#
# (a) (1 pt) True or False: The methods listed in the `Queue` interface are fully implemented.
#
# Answer: False -- the interface has no implementation
#
# (b) (1 pt) What methods does the `ArrayQueue` data structure implement?
#
# Answer: `resize()` and methods from `Queue`
#
# (c) (1 pt) What methods does the `SLLQueue` data structure implement?
#
# Answer: `get_position()` and methods from `Queue`

# %% [markdown]
# ## RUN-TIME
#
# 1. (1 pt each) Determine the big-O run-time for each algorithm below.
#
# (a)
# `def clone(array):
# """ returns a copy of the given array """
#     copy = [] # 1 visit
#     for e in array: # iterates e times (length of array)
#         copy.append(e) # 1 visit per iteration
#     return copy # 1 visit`
#
# Answer:
# `copy = []` and `return copy` will both run 1 time, 2 in total.
# `for e in array` will iterate `e` times, `e` being the length of the array.
# `copy.append(e)` will be visited 1 time for every iteration.
# the total # of visits is `e*1+1`
# since `e` is basically `n`, f(n) = n
# by definition, g(n) = O(f(n))
# therefore, the run-time is O(e + 1), or O(n)
#
#
# (b)
# `def integer_div(a, b):
# """performs integer division a // b """
#     count = 0 # run 1 time
#     total = b # run 1 time
#     while total <= a: # iterates a/b times
#         total += b # 1 visit per iteration
#         count += 1 # 1 visit per iteration
#     return count # 1 visit`
#
# Answer:
# `while total <= a` will iterate a times.
# inside the `while` loop, there are 2 visits per iteration.
# return is visited 1 time.
# the total # of visits is `a/b`, multiplied by `2` and f(n) = 2a/b + 1
# by definition, g(n) = O(f(n))
# therefore, the run-time is O(2a/b + 1), or O(a/b)
#
# Further reading (https://inst.eecs.berkeley.edu/~cs10/labs/cur/programming/algorithms/timing/constant-time.html?topic=berkeley_bjc%2Fareas%2Falgorithm-complexity.topic) and (https://hackernoon.com/big-o-for-beginners-622a64760e2) and (https://en.wikipedia.org/wiki/Computational_complexity_of_mathematical_operations) and (https://www.cse.iitk.ac.in/users/manindra/CS681/lecture1and2.pdf)
#
# (c)
# `def mod(a : int, b : int):
# """returns the remainder of a divided by b"""
#     if b <= 0: # 1 visit
#         return -100 # 1 visit
#     quotient = a // b # 1 visit
#     return a - quotient * b # 1 visit`
#
# Answer:
# `if b <= 0` will be visited 1 time
# `quotient = a // b` will be visited 1 time
# the `return` statements are visited once each.
# the total # of visits is `1+1+1+1` = `4` and f(n) = 4
# by definition, g(n) = O(f(n))
# therefore, the run-time is O(4), or O(1)
#
#
# 2. (1 pts) Which of the following are equivalent to `O(N)`? Why?
# - `O(4N)`
# — `O(N + 3P) where P < N/3`
# - `O(N + log N)`
# - `O(N + N log N)`
# - `O(N + M)`
#
# Answer:
#
# O(4N) is equivalent to O(N) because 4 is a coefficient and you can drop the coefficient of the dominant term (in this case, is N).
# O(N + 3P) is also equivalent to O(N) 3P is less than 3N/2 and can be written as O(N + 3N/2) = O(4N/2) = O(2N) = O(N).
# O(N + log N) is also equivalent to O(N) because N is the dominant term and can be written as O(N).
# O(N + M) is also equivalent to O(N) because M is smaller than N, according to the professor, leaving N as the dominant term. O(N + M) can be written as O(N).
